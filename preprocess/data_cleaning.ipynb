# %%
import matplotlib.pyplot as plt
import seaborn as sns
import glob
import os.path as osp
import pandas as pd

# %%
ROOT = './'

csv_data = glob.glob(f"{osp.join(ROOT, 'processed_data', '*.csv')}")
assert len(csv_data) > 0, "No csv files are found"

print(f"Found {len(csv_data)} csv files")
# Out:
# Found 7 csv files

# %%
AGE_CSV = '/Users/kctey/Desktop/NUS Y4S1/BN4101/UK_Biobank/processed_data/age.csv'

df = None
for filepath in sorted(csv_data)[::-1]:
    if df is None:
        df = pd.read_csv(filepath)
    else:
        tmp_df = pd.read_csv(filepath)
        
        # inner join age dataframe
        if filepath == AGE_CSV:
            how = 'inner'
        else:
            how = 'outer'  # outer join all cognitive tests and use imputation to fill missing values

        df = df.merge(tmp_df, on='subject_id', how=how)

# %%
df
# Out:
#         subject_id  Total time (numeric trail)  \
# 0          1000085                      43.202
# 1          1000158                      48.845
# 2          1000251                      23.656
# 3          1000279                      25.344
# 4          1000295                      33.183
# ...            ...                         ...
# 502406     6024887                         NaN
# 502407     6024893                         NaN
# 502408     6024902                         NaN
# 502409     6024915                         NaN
# 502410     6024921                         NaN
#
#         Total time (alphanumeric trail)  Total error (numeric path)  \
# 0                                64.591                         0.0
# 1                                96.175                         3.0
# 2                                36.673                         0.0
# 3                                51.384                         0.0
# 4                                52.936                         0.0
# ...                                 ...                         ...
# 502406                              NaN                         NaN
# 502407                              NaN                         NaN
# 502408                              NaN                         NaN
# 502409                              NaN                         NaN
# 502410                              NaN                         NaN
#
#         Total error (alphanumeric path)  Correct Digits matched  \
# 0                                   0.0                    22.0
# 1                                   5.0                     5.0
# 2                                   0.0                    23.0
# 3                                   1.0                    25.0
# 4                                   0.0                    21.0
# ...                                 ...                     ...
# 502406                              NaN                     NaN
# 502407                              NaN                     NaN
# 502408                              NaN                     NaN
# 502409                              NaN                     NaN
# 502410                              NaN                     NaN
#
#         Digit Match attempts  Mean Correct Pair  Mean Incorrect Pair  \
# 0                       22.0           4.500000             1.000000
# 1                       17.0           4.500000             5.000000
# 2                       24.0           4.500000             4.000000
# 3                       25.0           5.666667             3.333333
# 4                       21.0           4.500000             6.000000
# ...                      ...                ...                  ...
# 502406                   NaN                NaN                  NaN
# 502407                   NaN                NaN                  NaN
# 502408                   NaN                NaN                  NaN
# 502409                   NaN                NaN                  NaN
# 502410                   NaN                NaN                  NaN
#
#         Mean Completion Time  Maximum digits remembered correctly  gender  \
# 0                    22838.0                                  9.0       0
# 1                    35523.0                                  7.0       0
# 2                    14591.0                                  8.0       1
# 3                    21993.0                                  8.0       0
# 4                    32468.0                                  7.0       0
# ...                      ...                                  ...     ...
# 502406                   NaN                                  NaN       1
# 502407                   NaN                                  NaN       0
# 502408                   NaN                                  NaN       1
# 502409                   NaN                                  NaN       1
# 502410                   NaN                                  NaN       0
#
#         FI_score   age
# 0            6.0  51.0
# 1            5.0  60.0
# 2           10.0  53.0
# 3            4.0  54.0
# 4            6.0  57.0
# ...          ...   ...
# 502406       NaN  65.0
# 502407       NaN  44.0
# 502408       NaN  44.0
# 502409       NaN  41.0
# 502410       NaN  45.0
#
# [502411 rows x 14 columns]

# %% [markdown]
# # Feature Engineering
# 1. Accuracy Rate for symbol digit substitution
# 2. Accuracy rate for pair matching
#
# ### Total 9 cognitive related variables

# %%
# 1. symbol digit substitution -> calculate accuracy rate from correct digit matched and digit matched attempts
df['Symbol Digit Substitution Accuracy'] = df['Correct Digits matched']/df['Digit Match attempts']

# 2. Calculate accuracy -> mean correct pair/mean incorrect pair
df['Pair Matching Accuracy'] = df['Mean Correct Pair']/df['Mean Incorrect Pair']

# %% [markdown]
# # Dropping participants
#
# 1. Remove participants from trail making with too high of a completion time
# 2. Pair matching timing as -1 **(drop 2994) = 117043 + 2994 = 120037**
# 3. Participants who have sat for more than half the tests (arbitrary) **(left 117043)**

# %% [markdown]
# ### First drop participants who did not even complete half the tests

# %%
print("Length before droppping, ", len(df))
# drop participants who took less than 5 tests
drop_df = df.dropna(thresh=8)
print("Length after droppping, ", len(drop_df))

print("Dropped a total of ", len(df) - len(drop_df), " rows")
# Out:
# Length before droppping,  502411
# Length after droppping,  121176
# Dropped a total of  381235  rows

# %%
# drop participants with exceptionally high completion time
drop_df.sort_values('Mean Completion Time', ascending=False)
# Out:
#         subject_id  Total time (numeric trail)  \
# 118755     5386189                         NaN
# 120377     5879067                         NaN
# 116857     4833827                         NaN
# 38808      2856528                      82.976
# 116981     4871679                         NaN
# ...            ...                         ...
# 120810     6003875                         NaN
# 120838     6012231                         NaN
# 120839     6012410                         NaN
# 120852     6015545                         NaN
# 120878     6024392                         NaN
#
#         Total time (alphanumeric trail)  Total error (numeric path)  \
# 118755                              NaN                         NaN
# 120377                              NaN                         NaN
# 116857                              NaN                         NaN
# 38808                           100.688                         1.0
# 116981                              NaN                         NaN
# ...                                 ...                         ...
# 120810                              NaN                         NaN
# 120838                              NaN                         NaN
# 120839                              NaN                         NaN
# 120852                              NaN                         NaN
# 120878                              NaN                         NaN
#
#         Total error (alphanumeric path)  Correct Digits matched  \
# 118755                              NaN                     0.0
# 120377                              NaN                    14.0
# 116857                              NaN                    16.0
# 38808                               0.0                    10.0
# 116981                              NaN                    14.0
# ...                                 ...                     ...
# 120810                              NaN                    12.0
# 120838                              NaN                    14.0
# 120839                              NaN                    15.0
# 120852                              NaN                    15.0
# 120878                              NaN                    22.0
#
#         Digit Match attempts  Mean Correct Pair  Mean Incorrect Pair  \
# 118755                  14.0                4.5                  4.5
# 120377                  16.0                4.5                 10.0
# 116857                  16.0                4.5                 13.0
# 38808                   10.0                4.5                  5.0
# 116981                  14.0                4.5                  7.5
# ...                      ...                ...                  ...
# 120810                  13.0                NaN                  NaN
# 120838                  17.0                NaN                  NaN
# 120839                  15.0                NaN                  NaN
# 120852                  15.0                NaN                  NaN
# 120878                  22.0                NaN                  NaN
#
#         Mean Completion Time  Maximum digits remembered correctly  gender  \
# 118755               94984.0                                  5.0       0
# 120377               94799.5                                  NaN       1
# 116857               94516.5                                  6.0       1
# 38808                92039.5                                  6.0       1
# 116981               91783.5                                  7.0       0
# ...                      ...                                  ...     ...
# 120810                   NaN                                  6.0       1
# 120838                   NaN                                  7.0       1
# 120839                   NaN                                  5.0       0
# 120852                   NaN                                  6.0       1
# 120878                   NaN                                  8.0       1
#
#         FI_score   age  Symbol Digit Substitution Accuracy  \
# 118755       5.0  68.0                            0.000000
# 120377       4.0  67.0                            0.875000
# 116857       4.0  58.0                            1.000000
# 38808        5.0  68.0                            1.000000
# 116981       4.0  58.0                            1.000000
# ...          ...   ...                                 ...
# 120810       7.0  69.0                            0.923077
# 120838       8.0  62.0                            0.823529
# 120839       7.0  61.0                            1.000000
# 120852       5.0  62.0                            1.000000
# 120878       7.0  58.0                            1.000000
#
#         Pair Matching Accuracy
# 118755                1.000000
# 120377                0.450000
# 116857                0.346154
# 38808                 0.900000
# 116981                0.600000
# ...                        ...
# 120810                     NaN
# 120838                     NaN
# 120839                     NaN
# 120852                     NaN
# 120878                     NaN
#
# [121176 rows x 16 columns]

# %%
correct_45 = drop_df[drop_df['Mean Correct Pair'] == 4.5]['Mean Completion Time']
print(f"On average, participants take {correct_45.mean()} deciseconds to complete pair matching")
print(f"At max, participants take {correct_45.max()} deciseconds to complete pair matching")
print(f"At least, participants take {correct_45.min()} deciseconds to complete pair matching")

drop_df[drop_df['Mean Correct Pair'] == 4.5]['Mean Completion Time'].plot.box()
plt.title('Mean Completion Time box plot')
# Out:
# On average, participants take 23622.866854090244 deciseconds to complete pair matching
# At max, participants take 94984.0 deciseconds to complete pair matching
# At least, participants take 2173.5 deciseconds to complete pair matching
# Text(0.5, 1.0, 'Mean Completion Time box plot')

# %% [markdown]
# ### Drop participants with completion time which are too high

# %%
# drop by quantile

drop_df[drop_df['Mean Completion Time'] > drop_df['Mean Completion Time'].quantile(0.9)]
# Out:
#         subject_id  Total time (numeric trail)  \
# 7          1000403                      30.462
# 13         1000696                      23.612
# 17         1000952                      38.377
# 26         1001446                      53.991
# 70         1003545                      38.307
# ...            ...                         ...
# 121787     5758128                         NaN
# 121803     5829880                         NaN
# 121805     5848654                         NaN
# 121838     6009918                         NaN
# 121840     6014311                         NaN
#
#         Total time (alphanumeric trail)  Total error (numeric path)  \
# 7                                48.507                         0.0
# 13                               33.078                         0.0
# 17                               68.022                         0.0
# 26                               66.607                         0.0
# 70                               76.761                         0.0
# ...                                 ...                         ...
# 121787                              NaN                         NaN
# 121803                              NaN                         NaN
# 121805                              NaN                         NaN
# 121838                              NaN                         NaN
# 121840                              NaN                         NaN
#
#         Total error (alphanumeric path)  Correct Digits matched  \
# 7                                   0.0                    22.0
# 13                                  0.0                    24.0
# 17                                  0.0                    15.0
# 26                                  0.0                    16.0
# 70                                  1.0                    14.0
# ...                                 ...                     ...
# 121787                              NaN                     NaN
# 121803                              NaN                     NaN
# 121805                              NaN                     NaN
# 121838                              NaN                     NaN
# 121840                              NaN                     NaN
#
#         Digit Match attempts  Mean Correct Pair  Mean Incorrect Pair  \
# 7                       22.0           4.500000             7.500000
# 13                      24.0           5.666667             3.333333
# 17                      15.0           4.500000             3.500000
# 26                      16.0           4.500000             3.000000
# 70                      14.0           4.500000             6.500000
# ...                      ...                ...                  ...
# 121787                   NaN           4.500000            10.000000
# 121803                   NaN           4.500000             4.500000
# 121805                   NaN           4.500000             6.000000
# 121838                   NaN           4.500000             6.000000
# 121840                   NaN           4.500000             6.500000
#
#         Mean Completion Time  Maximum digits remembered correctly  gender  \
# 7               38399.000000                                  7.0       1
# 13              38399.666667                                  7.0       0
# 17              51749.000000                                  7.0       0
# 26              40940.500000                                  8.0       1
# 70              45198.500000                                  8.0       0
# ...                      ...                                  ...     ...
# 121787          49914.000000                                  NaN       1
# 121803          45153.000000                                  6.0       0
# 121805          70514.500000                                  7.0       1
# 121838          36960.000000                                  4.0       1
# 121840          64201.000000                                  5.0       1
#
#         FI_score   age  Symbol Digit Substitution Accuracy  \
# 7            4.0  41.0                                 1.0
# 13           9.0  55.0                                 1.0
# 17           6.0  54.0                                 1.0
# 26           7.0  60.0                                 1.0
# 70           7.0  68.0                                 1.0
# ...          ...   ...                                 ...
# 121787       3.0  66.0                                 NaN
# 121803       5.0  61.0                                 NaN
# 121805       2.0  65.0                                 NaN
# 121838       2.0  64.0                                 NaN
# 121840       4.0  55.0                                 NaN
#
#         Pair Matching Accuracy
# 7                     0.600000
# 13                    1.700000
# 17                    1.285714
# 26                    1.500000
# 70                    0.692308
# ...                        ...
# 121787                0.450000
# 121803                1.000000
# 121805                0.750000
# 121838                0.750000
# 121840                0.692308
#
# [11550 rows x 16 columns]

# %%
drop_df = drop_df[drop_df['Mean Completion Time'] <= drop_df['Mean Completion Time'].quantile(0.9)]
print(f"Left with {len(drop_df)} rows")
# Out:
# Left with 103951 rows

# %%
cols_to_remove = [
    'Correct Digits matched', 'Digit Match attempts', 'Mean Correct Pair', 'Mean Incorrect Pair'
]
new_df = drop_df.drop(cols_to_remove, axis=1)
new_df
# Out:
#         subject_id  Total time (numeric trail)  \
# 0          1000085                      43.202
# 1          1000158                      48.845
# 2          1000251                      23.656
# 3          1000279                      25.344
# 4          1000295                      33.183
# ...            ...                         ...
# 121836     6000260                         NaN
# 121837     6001089                         NaN
# 121839     6011793                         NaN
# 121841     6014493                         NaN
# 121842     6020913                         NaN
#
#         Total time (alphanumeric trail)  Total error (numeric path)  \
# 0                                64.591                         0.0
# 1                                96.175                         3.0
# 2                                36.673                         0.0
# 3                                51.384                         0.0
# 4                                52.936                         0.0
# ...                                 ...                         ...
# 121836                              NaN                         NaN
# 121837                              NaN                         NaN
# 121839                              NaN                         NaN
# 121841                              NaN                         NaN
# 121842                              NaN                         NaN
#
#         Total error (alphanumeric path)  Mean Completion Time  \
# 0                                   0.0          22838.000000
# 1                                   5.0          35523.000000
# 2                                   0.0          14591.000000
# 3                                   1.0          21993.000000
# 4                                   0.0          32468.000000
# ...                                 ...                   ...
# 121836                              NaN          15661.500000
# 121837                              NaN          14432.000000
# 121839                              NaN          16046.500000
# 121841                              NaN          21785.000000
# 121842                              NaN          24100.333333
#
#         Maximum digits remembered correctly  gender  FI_score   age  \
# 0                                       9.0       0       6.0  51.0
# 1                                       7.0       0       5.0  60.0
# 2                                       8.0       1      10.0  53.0
# 3                                       8.0       0       4.0  54.0
# 4                                       7.0       0       6.0  57.0
# ...                                     ...     ...       ...   ...
# 121836                                  5.0       1       4.0  62.0
# 121837                                  7.0       0       5.0  55.0
# 121839                                  7.0       0       6.0  66.0
# 121841                                  6.0       0       6.0  64.0
# 121842                                  7.0       1       NaN  44.0
#
#         Symbol Digit Substitution Accuracy  Pair Matching Accuracy
# 0                                 1.000000                   4.500
# 1                                 0.294118                   0.900
# 2                                 0.958333                   1.125
# 3                                 1.000000                   1.700
# 4                                 1.000000                   0.750
# ...                                    ...                     ...
# 121836                                 NaN                   3.000
# 121837                                 NaN                   2.250
# 121839                                 NaN                   2.250
# 121841                                 NaN                   2.250
# 121842                                 NaN                   3.400
#
# [103951 rows x 12 columns]

# %%
# use this new_df as the master dataset
new_df.to_csv('master.csv', index=False)

# %%
# visualize missing values

plt.figure(figsize=(10,6))
sns.heatmap(new_df.isna().transpose(),
            cmap="YlGnBu",
            cbar_kws={'label': 'Missing Data'})
plt.show()

# %%
matrix = new_df.corr()
sns.heatmap(matrix, annot=True, fmt=".1f", xticklabels=False)
# Out:
# <AxesSubplot:>

# %%
from scipy.stats import *
male_fi = new_df[new_df['gender'] == 1]['FI_score'].dropna()
female_fi = new_df[new_df['gender'] == 0]['FI_score'].dropna()
twotail = ttest_ind(male_fi, female_fi, equal_var=True)
twotail
# Out:
# Ttest_indResult(statistic=16.96868061694174, pvalue=1.7155392897764528e-64)

# %%
print("female: ", female_fi.mean(), female_fi.std(), len(female_fi))
print("male: ", male_fi.mean(), male_fi.std(), len(male_fi))
# Out:
# female:  6.4813164149888145 1.988308162240329 57216
# male:  6.697636027469625 2.078394811375244 45432

# %%
new_df.age.describe()
# Out:
# count    103951.00000
# mean         55.50164
# std           7.69507
# min          38.00000
# 25%          49.00000
# 50%          56.00000
# 75%          62.00000
# max          70.00000
# Name: age, dtype: float64

# %%
from scipy.stats import norm

# new_df.age.plot.density()
# plt.title('Age Distribution in the UK Biobank dataset')
# plt.show()

(mu, sigma) = norm.fit(new_df['age'])
sns.distplot(new_df['age'] , fit=norm)

plt.legend(['Normal dist. ($\mu=$ {:.2f} and $\sigma=$ {:.2f} )'.format(mu, sigma)])
plt.ylabel('Frequency')
plt.title('Age distribution')
plt.show()
# Out:
# /var/folders/ky/dl08g4ws1rq302s4gkqyh6cr0000gn/T/ipykernel_3741/4250736200.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_df['age'] , fit=norm)

# %%
gender_col = new_df['gender'].astype(str)

# %%
gender_col.value_counts()
# Out:
# 0    58042
# 1    45909
# Name: gender, dtype: int64

# %%
fig1, ax1 = plt.subplots()
labels = ['female', 'male']
ax1.pie(gender_col.value_counts(), labels=labels, autopct='%1.1f%%')
ax1.set_title('Gender distribution in the UK Biobank dataset')
# Out:
# Text(0.5, 1.0, 'Gender distribution in the UK Biobank dataset')

# %% [markdown]
# # Check data normality

# %%
# FI
# plt.hist(df['20191-0.0'])
# plt.show()

# from scipy.stats import shapiro
# shapiro(df['20191-0.0'].dropna()) # ShapiroResult(statistic=0.9766396880149841, pvalue=0.0)

# from scipy.stats import kstest
# kstest(df['20191-0.0'].dropna(), 'norm') # KstestResult(statistic=0.9823087568599015, pvalue=0.0)

# %% [markdown]
# # Handle Missing Values
